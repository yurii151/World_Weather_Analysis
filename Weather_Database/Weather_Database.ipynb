# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
from citipy import citipy

# %%
#Create a set of randon latitude and longitude values
lats = np.random.uniform(low= -90, high = 90, size = 2000)
longs = np.random.uniform(low = -180 , high = 180, size = 2000)
lat_lngs = zip(lats,longs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" +weather_api_key

# %%
import time

# %%
#Create a list to hold the data 
city_data= []

#Print the beginning of the logging 
print('Beginning data retrieval')
print('-----------------------')
print('-----------------------')

#Create counters
record_count=1
set_count=1


#Loop through all the cities in our list 
for i, city in enumerate(cities):
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint url for each city 
    city_url=url + '&q='+city.replace(" ","+")
    
   #Log the URL, record ,and set numbers and city.
    print(f"Processing Record {record_count} of Set {set_count}|{city}")
   #Add 1 to the record count
    record_count +=1
    
    #Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data 
        city_weather = requests.get(city_url).json()
            
#              #Get the weather description from the weather list
#         for weather in city_weather['weather']:
#             description = weather.get('description')
            
        #Parse the data needed 
        city_lat= city_weather['coord']['lat']
        city_lng= city_weather['coord']['lon']
        city_max_temp= city_weather['main']['temp_max']
        city_humidity= city_weather['main']['humidity']
        city_clouds= city_weather['clouds']['all']
        city_wind= city_weather['wind']['speed']
        city_country= city_weather['sys']['country']
        city_description=city_weather['weather'][0]['description']
         #Append the city information into the city_data list
        city_data.append({"City":city.title(),
                            "Country":city_country,
                            "Lat" : city_lat,
                            "Lng":city_lng,
                           "Max Temp":city_max_temp,
                            "Humidity":city_humidity,
                           "Cloudiness":city_clouds,
                           "Wind Speed":city_wind,
                            "Current Description":city_description})
                           
            
            
# If an error is experienced , skip the city
    except:
          print("City not found, skipping..")
    pass
          
#Indicate the data loading is complete 
print("------------------")
print ("Data Retrieval Complete")
print("------------------")
# Out:
# Beginning data retrieval
# -----------------------
# -----------------------
# Processing Record 1 of Set 1|jerez
# Processing Record 2 of Set 1|saldanha
# Processing Record 3 of Set 1|norman wells
# Processing Record 4 of Set 1|butaritari
# Processing Record 5 of Set 1|den helder
# Processing Record 6 of Set 1|tuggurt
# City not found, skipping..
# Processing Record 7 of Set 1|thompson
# Processing Record 8 of Set 1|fort morgan
# Processing Record 9 of Set 1|ushuaia
# Processing Record 10 of Set 1|madison
# Processing Record 11 of Set 1|boralday
# Processing Record 12 of Set 1|lashio
# Processing Record 13 of Set 1|east london
# Processing Record 14 of Set 1|mataura
# Processing Record 15 of Set 1|tsabong
# Processing Record 16 of Set 1|mys shmidta
# City not found, skipping..
# Processing Record 17 of Set 1|taolanaro
# City not found, skipping..
# Processing Record 18 of Set 1|tianpeng
# Processing Record 19 of Set 1|arraial do cabo
# Processing Record 20 of Set 1|sao joao da barra
# Processing Record 21 of Set 1|parrita
# Processing Record 22 of Set 1|atuona
# Processing Record 23 of Set 1|illoqqortoormiut
# City not found, skipping..
# Processing Record 24 of Set 1|mar del plata
# Processing Record 25 of Set 1|grindavik
# Processing Record 26 of Set 1|bathsheba
# Processing Record 27 of Set 1|tuktoyaktuk
# Processing Record 28 of Set 1|severo-kurilsk
# Processing Record 29 of Set 1|yanan
# City not found, skipping..
# Processing Record 30 of Set 1|cabo san lucas
# Processing Record 31 of Set 1|puri
# Processing Record 32 of Set 1|aliwal north
# Processing Record 33 of Set 1|kuytun
# Processing Record 34 of Set 1|rikitea
# Processing Record 35 of Set 1|tanete
# Processing Record 36 of Set 1|clyde river
# Processing Record 37 of Set 1|iquique
# Processing Record 38 of Set 1|puerto ayora
# Processing Record 39 of Set 1|esso
# Processing Record 40 of Set 1|dikson
# Processing Record 41 of Set 1|rocha
# Processing Record 42 of Set 1|warqla
# City not found, skipping..
# Processing Record 43 of Set 1|tasiilaq
# Processing Record 44 of Set 1|vaini
# Processing Record 45 of Set 1|castro
# Processing Record 46 of Set 1|avarua
# Processing Record 47 of Set 1|khatanga
# Processing Record 48 of Set 1|hobart
# Processing Record 49 of Set 1|manicore
# Processing Record 50 of Set 1|mgachi
# Processing Record 1 of Set 2|chokurdakh
# Processing Record 2 of Set 2|salalah
# Processing Record 3 of Set 2|ust-nera
# Processing Record 4 of Set 2|muros
# Processing Record 5 of Set 2|provideniya
# Processing Record 6 of Set 2|mahebourg
# Processing Record 7 of Set 2|punta arenas
# Processing Record 8 of Set 2|souillac
# Processing Record 9 of Set 2|new norfolk
# Processing Record 10 of Set 2|busselton
# Processing Record 11 of Set 2|viedma
# Processing Record 12 of Set 2|belyy yar
# Processing Record 13 of Set 2|belushya guba
# City not found, skipping..
# Processing Record 14 of Set 2|kluczbork
# Processing Record 15 of Set 2|kapaa
# Processing Record 16 of Set 2|baruun-urt
# Processing Record 17 of Set 2|luderitz
# Processing Record 18 of Set 2|ilulissat
# Processing Record 19 of Set 2|safaga
# Processing Record 20 of Set 2|kidal
# Processing Record 21 of Set 2|tigil
# Processing Record 22 of Set 2|hermanus
# Processing Record 23 of Set 2|guacimo
# Processing Record 24 of Set 2|cape town
# Processing Record 25 of Set 2|mocambique
# City not found, skipping..
# Processing Record 26 of Set 2|fortuna
# Processing Record 27 of Set 2|yellowknife
# Processing Record 28 of Set 2|cherskiy
# Processing Record 29 of Set 2|huarmey
# Processing Record 30 of Set 2|moroni
# Processing Record 31 of Set 2|victoria
# Processing Record 32 of Set 2|port elizabeth
# Processing Record 33 of Set 2|albany
# Processing Record 34 of Set 2|santa maria
# Processing Record 35 of Set 2|saint-augustin
# Processing Record 36 of Set 2|price
# Processing Record 37 of Set 2|barentsburg
# City not found, skipping..
# Processing Record 38 of Set 2|agadez
# Processing Record 39 of Set 2|karauzyak
# City not found, skipping..
# Processing Record 40 of Set 2|saint pete beach
# Processing Record 41 of Set 2|bredasdorp
# Processing Record 42 of Set 2|rovaniemi
# Processing Record 43 of Set 2|ketchikan
# Processing Record 44 of Set 2|bilibino
# Processing Record 45 of Set 2|inuvik
# Processing Record 46 of Set 2|georgetown
# Processing Record 47 of Set 2|ancud
# Processing Record 48 of Set 2|airai
# Processing Record 49 of Set 2|iqaluit
# Processing Record 50 of Set 2|port alfred
# Processing Record 1 of Set 3|bluff
# Processing Record 2 of Set 3|amderma
# City not found, skipping..
# Processing Record 3 of Set 3|hun
# Processing Record 4 of Set 3|torbay
# Processing Record 5 of Set 3|fort frances
# Processing Record 6 of Set 3|cidreira
# Processing Record 7 of Set 3|hilo
# Processing Record 8 of Set 3|port hardy
# Processing Record 9 of Set 3|morondava
# Processing Record 10 of Set 3|acapulco
# Processing Record 11 of Set 3|qaqortoq
# Processing Record 12 of Set 3|qaanaaq
# Processing Record 13 of Set 3|isetskoye
# Processing Record 14 of Set 3|saint-philippe
# Processing Record 15 of Set 3|vidra
# Processing Record 16 of Set 3|rungata
# City not found, skipping..
# Processing Record 17 of Set 3|preobrazheniye
# Processing Record 18 of Set 3|ternate
# Processing Record 19 of Set 3|nome
# Processing Record 20 of Set 3|barrow
# Processing Record 21 of Set 3|bengkulu
# Processing Record 22 of Set 3|lypova dolyna
# Processing Record 23 of Set 3|saleaula
# City not found, skipping..
# Processing Record 24 of Set 3|jamestown
# Processing Record 25 of Set 3|khanpur
# Processing Record 26 of Set 3|plettenberg bay
# Processing Record 27 of Set 3|nizhneyansk
# City not found, skipping..
# Processing Record 28 of Set 3|gushikawa
# Processing Record 29 of Set 3|santa fe
# Processing Record 30 of Set 3|nikolskoye
# Processing Record 31 of Set 3|ito
# Processing Record 32 of Set 3|sataua
# City not found, skipping..
# Processing Record 33 of Set 3|lavrentiya
# Processing Record 34 of Set 3|tsihombe
# City not found, skipping..
# Processing Record 35 of Set 3|ipinda
# Processing Record 36 of Set 3|kodiak
# Processing Record 37 of Set 3|urucui
# Processing Record 38 of Set 3|attawapiskat
# City not found, skipping..
# Processing Record 39 of Set 3|aban
# Processing Record 40 of Set 3|bandarbeyla
# Processing Record 41 of Set 3|chernyshevskiy
# Processing Record 42 of Set 3|kermanshah
# Processing Record 43 of Set 3|goderich
# Processing Record 44 of Set 3|alice springs
# Processing Record 45 of Set 3|saint-francois
# Processing Record 46 of Set 3|ribeira grande
# Processing Record 47 of Set 3|esperance
# Processing Record 48 of Set 3|upernavik
# Processing Record 49 of Set 3|cockburn town
# Processing Record 50 of Set 3|vila velha
# Processing Record 1 of Set 4|vardo
# Processing Record 2 of Set 4|marcona
# City not found, skipping..
# Processing Record 3 of Set 4|mayumba
# Processing Record 4 of Set 4|pevek
# Processing Record 5 of Set 4|sinnamary
# Processing Record 6 of Set 4|nador
# Processing Record 7 of Set 4|hamilton
# Processing Record 8 of Set 4|usevya
# Processing Record 9 of Set 4|carnarvon
# Processing Record 10 of Set 4|mayo
# Processing Record 11 of Set 4|kendari
# Processing Record 12 of Set 4|santiago
# Processing Record 13 of Set 4|henties bay
# Processing Record 14 of Set 4|faanui
# Processing Record 15 of Set 4|folldal
# Processing Record 16 of Set 4|manado
# Processing Record 17 of Set 4|nuuk
# Processing Record 18 of Set 4|makakilo city
# Processing Record 19 of Set 4|lagoa
# Processing Record 20 of Set 4|korla
# Processing Record 21 of Set 4|narsaq
# Processing Record 22 of Set 4|karratha
# Processing Record 23 of Set 4|piro
# Processing Record 24 of Set 4|along
# Processing Record 25 of Set 4|sechura
# Processing Record 26 of Set 4|lasa
# Processing Record 27 of Set 4|hokitika
# Processing Record 28 of Set 4|ijui
# Processing Record 29 of Set 4|senneterre
# Processing Record 30 of Set 4|bethel
# Processing Record 31 of Set 4|hanyang
# Processing Record 32 of Set 4|saskylakh
# Processing Record 33 of Set 4|portland
# Processing Record 34 of Set 4|abrau-dyurso
# Processing Record 35 of Set 4|hambantota
# Processing Record 36 of Set 4|lufkin
# Processing Record 37 of Set 4|quelimane
# Processing Record 38 of Set 4|san patricio
# Processing Record 39 of Set 4|cayenne
# Processing Record 40 of Set 4|broome
# Processing Record 41 of Set 4|san juan
# Processing Record 42 of Set 4|katsiveli
# City not found, skipping..
# Processing Record 43 of Set 4|desur
# Processing Record 44 of Set 4|nyurba
# Processing Record 45 of Set 4|longyearbyen
# Processing Record 46 of Set 4|zhigansk
# Processing Record 47 of Set 4|alofi
# Processing Record 48 of Set 4|murgab
# Processing Record 49 of Set 4|koboko
# Processing Record 50 of Set 4|tiznit
# Processing Record 1 of Set 5|north branch
# Processing Record 2 of Set 5|davidson
# Processing Record 3 of Set 5|comodoro rivadavia
# Processing Record 4 of Set 5|paamiut
# Processing Record 5 of Set 5|katsuura
# Processing Record 6 of Set 5|flinders
# Processing Record 7 of Set 5|oktyabrskoye
# Processing Record 8 of Set 5|porto walter
# Processing Record 9 of Set 5|leh
# Processing Record 10 of Set 5|sao jose da coroa grande
# Processing Record 11 of Set 5|kulhudhuffushi
# Processing Record 12 of Set 5|auki
# Processing Record 13 of Set 5|bambous virieux
# Processing Record 14 of Set 5|puerto baquerizo moreno
# Processing Record 15 of Set 5|wanning
# Processing Record 16 of Set 5|vicksburg
# Processing Record 17 of Set 5|kirundo
# Processing Record 18 of Set 5|katsina
# Processing Record 19 of Set 5|velasco ibarra
# Processing Record 20 of Set 5|luwuk
# Processing Record 21 of Set 5|tumannyy
# City not found, skipping..
# Processing Record 22 of Set 5|tiksi
# Processing Record 23 of Set 5|abha
# Processing Record 24 of Set 5|kloulklubed
# Processing Record 25 of Set 5|wiang sa
# Processing Record 26 of Set 5|mbengwi
# Processing Record 27 of Set 5|porangatu
# Processing Record 28 of Set 5|sisimiut
# Processing Record 29 of Set 5|el badari
# City not found, skipping..
# Processing Record 30 of Set 5|istanbul
# Processing Record 31 of Set 5|mpika
# Processing Record 32 of Set 5|mount pleasant
# Processing Record 33 of Set 5|sarakhs
# Processing Record 34 of Set 5|camacha
# Processing Record 35 of Set 5|stoyba
# City not found, skipping..
# Processing Record 36 of Set 5|muskogee
# Processing Record 37 of Set 5|fort nelson
# Processing Record 38 of Set 5|sheridan
# Processing Record 39 of Set 5|gloucester
# Processing Record 40 of Set 5|hays
# Processing Record 41 of Set 5|elko
# Processing Record 42 of Set 5|kaitangata
# Processing Record 43 of Set 5|belaya gora
# Processing Record 44 of Set 5|saint-pierre
# Processing Record 45 of Set 5|aksarka
# Processing Record 46 of Set 5|puerto cortes
# City not found, skipping..
# Processing Record 47 of Set 5|labuan
# Processing Record 48 of Set 5|tubruq
# City not found, skipping..
# Processing Record 49 of Set 5|ponta do sol
# Processing Record 50 of Set 5|kirkwall
# Processing Record 1 of Set 6|burica
# City not found, skipping..
# Processing Record 2 of Set 6|maniitsoq
# Processing Record 3 of Set 6|hithadhoo
# Processing Record 4 of Set 6|yurty
# Processing Record 5 of Set 6|kaseda
# Processing Record 6 of Set 6|constitucion
# Processing Record 7 of Set 6|fairbanks
# Processing Record 8 of Set 6|ruatoria
# City not found, skipping..
# Processing Record 9 of Set 6|lebu
# Processing Record 10 of Set 6|mwinilunga
# Processing Record 11 of Set 6|hasaki
# Processing Record 12 of Set 6|arman
# Processing Record 13 of Set 6|los llanos de aridane
# Processing Record 14 of Set 6|marzuq
# Processing Record 15 of Set 6|port hedland
# Processing Record 16 of Set 6|westport
# Processing Record 17 of Set 6|meyungs
# City not found, skipping..
# Processing Record 18 of Set 6|general cepeda
# Processing Record 19 of Set 6|mount isa
# Processing Record 20 of Set 6|dangriga
# Processing Record 21 of Set 6|pangnirtung
# Processing Record 22 of Set 6|srednekolymsk
# Processing Record 23 of Set 6|moree
# Processing Record 24 of Set 6|necochea
# Processing Record 25 of Set 6|krasnoselkup
# Processing Record 26 of Set 6|prosvet
# Processing Record 27 of Set 6|lichinga
# Processing Record 28 of Set 6|kahului
# Processing Record 29 of Set 6|awbari
# Processing Record 30 of Set 6|neuquen
# Processing Record 31 of Set 6|prince rupert
# Processing Record 32 of Set 6|senanga
# Processing Record 33 of Set 6|juneau
# Processing Record 34 of Set 6|isangel
# Processing Record 35 of Set 6|nanortalik
# Processing Record 36 of Set 6|tres arroyos
# Processing Record 37 of Set 6|lubana
# Processing Record 38 of Set 6|progreso
# Processing Record 39 of Set 6|ye
# City not found, skipping..
# Processing Record 40 of Set 6|jose de freitas
# Processing Record 41 of Set 6|gobabis
# Processing Record 42 of Set 6|vigrestad
# Processing Record 43 of Set 6|chuy
# Processing Record 44 of Set 6|coihaique
# Processing Record 45 of Set 6|scottsbluff
# Processing Record 46 of Set 6|talnakh
# Processing Record 47 of Set 6|jaguey grande
# Processing Record 48 of Set 6|maues
# Processing Record 49 of Set 6|batemans bay
# Processing Record 50 of Set 6|bhadasar
# Processing Record 1 of Set 7|kama
# Processing Record 2 of Set 7|lorengau
# Processing Record 3 of Set 7|mildura
# Processing Record 4 of Set 7|smirnykh
# Processing Record 5 of Set 7|tazovskiy
# Processing Record 6 of Set 7|bubaque
# Processing Record 7 of Set 7|ambodifototra
# City not found, skipping..
# Processing Record 8 of Set 7|soyo
# Processing Record 9 of Set 7|paita
# Processing Record 10 of Set 7|novoselitskoye
# Processing Record 11 of Set 7|powell river
# Processing Record 12 of Set 7|marawi
# Processing Record 13 of Set 7|pemba
# Processing Record 14 of Set 7|bur gabo
# City not found, skipping..
# Processing Record 15 of Set 7|paceco
# Processing Record 16 of Set 7|kharabali
# Processing Record 17 of Set 7|vaitupu
# City not found, skipping..
# Processing Record 18 of Set 7|ribas do rio pardo
# Processing Record 19 of Set 7|anloga
# Processing Record 20 of Set 7|malinovskiy
# Processing Record 21 of Set 7|smithers
# Processing Record 22 of Set 7|beyneu
# Processing Record 23 of Set 7|diamantino
# Processing Record 24 of Set 7|lodja
# Processing Record 25 of Set 7|tual
# Processing Record 26 of Set 7|ruteng
# Processing Record 27 of Set 7|saint george
# Processing Record 28 of Set 7|sao jose de piranhas
# Processing Record 29 of Set 7|eyl
# Processing Record 30 of Set 7|salta
# Processing Record 31 of Set 7|umzimvubu
# City not found, skipping..
# Processing Record 32 of Set 7|valdivia
# Processing Record 33 of Set 7|tarko-sale
# Processing Record 34 of Set 7|port blair
# Processing Record 35 of Set 7|kavaratti
# Processing Record 36 of Set 7|sitka
# Processing Record 37 of Set 7|balvi
# Processing Record 38 of Set 7|muroto
# Processing Record 39 of Set 7|bilma
# Processing Record 40 of Set 7|monchegorsk
# Processing Record 41 of Set 7|tunduru
# City not found, skipping..
# Processing Record 42 of Set 7|sur
# Processing Record 43 of Set 7|corinth
# Processing Record 44 of Set 7|sao filipe
# Processing Record 45 of Set 7|igarka
# Processing Record 46 of Set 7|wangkui
# Processing Record 47 of Set 7|kutum
# Processing Record 48 of Set 7|yeppoon
# Processing Record 49 of Set 7|medina
# Processing Record 50 of Set 7|vila
# Processing Record 1 of Set 8|morganton
# Processing Record 2 of Set 8|yerbogachen
# Processing Record 3 of Set 8|townsville
# Processing Record 4 of Set 8|daru
# Processing Record 5 of Set 8|mogadishu
# Processing Record 6 of Set 8|coquimbo
# Processing Record 7 of Set 8|guerrero negro
# Processing Record 8 of Set 8|svetlyy
# Processing Record 9 of Set 8|kruisfontein
# Processing Record 10 of Set 8|natchitoches
# Processing Record 11 of Set 8|lingao
# Processing Record 12 of Set 8|sharkan
# Processing Record 13 of Set 8|andenes
# Processing Record 14 of Set 8|aklavik
# Processing Record 15 of Set 8|grand river south east
# City not found, skipping..
# Processing Record 16 of Set 8|sarahan
# Processing Record 17 of Set 8|poum
# Processing Record 18 of Set 8|sikasso
# Processing Record 19 of Set 8|rio gallegos
# Processing Record 20 of Set 8|boyolangu
# Processing Record 21 of Set 8|chipata
# Processing Record 22 of Set 8|sibu
# Processing Record 23 of Set 8|riohacha
# Processing Record 24 of Set 8|haines junction
# Processing Record 25 of Set 8|aksu
# Processing Record 26 of Set 8|ostrovnoy
# Processing Record 27 of Set 8|santa cruz
# Processing Record 28 of Set 8|turukhansk
# Processing Record 29 of Set 8|amga
# Processing Record 30 of Set 8|labuhan
# Processing Record 31 of Set 8|gat
# Processing Record 32 of Set 8|cap malheureux
# Processing Record 33 of Set 8|ondorhaan
# City not found, skipping..
# Processing Record 34 of Set 8|maine-soroa
# Processing Record 35 of Set 8|nishihara
# Processing Record 36 of Set 8|burnie
# Processing Record 37 of Set 8|hobyo
# Processing Record 38 of Set 8|shenjiamen
# Processing Record 39 of Set 8|gizo
# Processing Record 40 of Set 8|pincher creek
# Processing Record 41 of Set 8|bako
# Processing Record 42 of Set 8|lagos
# Processing Record 43 of Set 8|alekseyevka
# Processing Record 44 of Set 8|margate
# Processing Record 45 of Set 8|mackay
# Processing Record 46 of Set 8|kamiiso
# Processing Record 47 of Set 8|perur
# Processing Record 48 of Set 8|nouadhibou
# Processing Record 49 of Set 8|tahta
# Processing Record 50 of Set 8|laguna
# Processing Record 1 of Set 9|leningradskiy
# Processing Record 2 of Set 9|ambilobe
# Processing Record 3 of Set 9|pisco
# Processing Record 4 of Set 9|kerman
# Processing Record 5 of Set 9|vila franca do campo
# Processing Record 6 of Set 9|ahipara
# Processing Record 7 of Set 9|sambava
# Processing Record 8 of Set 9|sistranda
# Processing Record 9 of Set 9|san quintin
# Processing Record 10 of Set 9|ballina
# Processing Record 11 of Set 9|sterling
# Processing Record 12 of Set 9|dingle
# Processing Record 13 of Set 9|fernie
# Processing Record 14 of Set 9|ucluelet
# Processing Record 15 of Set 9|point fortin
# Processing Record 16 of Set 9|dipalpur
# Processing Record 17 of Set 9|nagar karnul
# Processing Record 18 of Set 9|port lincoln
# Processing Record 19 of Set 9|shakawe
# Processing Record 20 of Set 9|college
# Processing Record 21 of Set 9|nurota
# Processing Record 22 of Set 9|corinto
# Processing Record 23 of Set 9|touros
# Processing Record 24 of Set 9|nalut
# Processing Record 25 of Set 9|nantucket
# Processing Record 26 of Set 9|bulnes
# Processing Record 27 of Set 9|caborca
# Processing Record 28 of Set 9|san-pedro
# Processing Record 29 of Set 9|vostok
# Processing Record 30 of Set 9|gurskoye
# City not found, skipping..
# Processing Record 31 of Set 9|vidalia
# Processing Record 32 of Set 9|west fargo
# Processing Record 33 of Set 9|anadyr
# Processing Record 34 of Set 9|kysyl-syr
# Processing Record 35 of Set 9|kalmunai
# Processing Record 36 of Set 9|birjand
# Processing Record 37 of Set 9|nicoya
# Processing Record 38 of Set 9|barcelona
# Processing Record 39 of Set 9|syamzha
# Processing Record 40 of Set 9|aasiaat
# Processing Record 41 of Set 9|puerto suarez
# Processing Record 42 of Set 9|tortoli
# Processing Record 43 of Set 9|finschhafen
# Processing Record 44 of Set 9|kabompo
# Processing Record 45 of Set 9|jackson
# Processing Record 46 of Set 9|jose bonifacio
# Processing Record 47 of Set 9|fukue
# Processing Record 48 of Set 9|bacuit
# City not found, skipping..
# Processing Record 49 of Set 9|wufeng
# Processing Record 50 of Set 9|shirokiy
# Processing Record 1 of Set 10|hirara
# Processing Record 2 of Set 10|srandakan
# Processing Record 3 of Set 10|louisbourg
# City not found, skipping..
# Processing Record 4 of Set 10|thinadhoo
# Processing Record 5 of Set 10|geraldton
# Processing Record 6 of Set 10|kamenskoye
# City not found, skipping..
# Processing Record 7 of Set 10|bertinoro
# Processing Record 8 of Set 10|gurupa
# Processing Record 9 of Set 10|komsomolskiy
# Processing Record 10 of Set 10|bagaces
# Processing Record 11 of Set 10|falam
# Processing Record 12 of Set 10|bogotol
# Processing Record 13 of Set 10|itoman
# Processing Record 14 of Set 10|camacupa
# Processing Record 15 of Set 10|tura
# Processing Record 16 of Set 10|san cristobal
# Processing Record 17 of Set 10|avera
# Processing Record 18 of Set 10|aswan
# Processing Record 19 of Set 10|plavsk
# Processing Record 20 of Set 10|dunayivtsi
# City not found, skipping..
# Processing Record 21 of Set 10|laramie
# Processing Record 22 of Set 10|kupang
# Processing Record 23 of Set 10|beloha
# Processing Record 24 of Set 10|uray
# Processing Record 25 of Set 10|te anau
# Processing Record 26 of Set 10|faya
# Processing Record 27 of Set 10|kirakira
# Processing Record 28 of Set 10|lompoc
# Processing Record 29 of Set 10|stolin
# Processing Record 30 of Set 10|san andres
# Processing Record 31 of Set 10|golden
# Processing Record 32 of Set 10|padang
# Processing Record 33 of Set 10|asau
# Processing Record 34 of Set 10|punta alta
# Processing Record 35 of Set 10|longlac
# City not found, skipping..
# Processing Record 36 of Set 10|dunmore town
# Processing Record 37 of Set 10|solnechnyy
# Processing Record 38 of Set 10|inirida
# Processing Record 39 of Set 10|joniskelis
# Processing Record 40 of Set 10|betioky
# Processing Record 41 of Set 10|port-de-paix
# City not found, skipping..
# Processing Record 42 of Set 10|dudinka
# Processing Record 43 of Set 10|carlsbad
# Processing Record 44 of Set 10|turtkul
# City not found, skipping..
# Processing Record 45 of Set 10|maragogi
# Processing Record 46 of Set 10|kota kinabalu
# Processing Record 47 of Set 10|kununurra
# Processing Record 48 of Set 10|puerto princesa
# Processing Record 49 of Set 10|pafos
# Processing Record 50 of Set 10|nelson bay
# Processing Record 1 of Set 11|taltal
# Processing Record 2 of Set 11|sri aman
# Processing Record 3 of Set 11|namatanai
# Processing Record 4 of Set 11|samusu
# City not found, skipping..
# Processing Record 5 of Set 11|tumut
# Processing Record 6 of Set 11|pital
# Processing Record 7 of Set 11|calawag
# Processing Record 8 of Set 11|klaksvik
# Processing Record 9 of Set 11|nsanje
# Processing Record 10 of Set 11|mastung
# Processing Record 11 of Set 11|lukulu
# Processing Record 12 of Set 11|olafsvik
# Processing Record 13 of Set 11|oppdal
# Processing Record 14 of Set 11|tumbes
# Processing Record 15 of Set 11|nanakuli
# Processing Record 16 of Set 11|hearst
# Processing Record 17 of Set 11|kuche
# City not found, skipping..
# Processing Record 18 of Set 11|havre-saint-pierre
# Processing Record 19 of Set 11|mendi
# Processing Record 20 of Set 11|derzhavinsk
# Processing Record 21 of Set 11|abu samrah
# Processing Record 22 of Set 11|altamira
# Processing Record 23 of Set 11|conceicao do araguaia
# Processing Record 24 of Set 11|la rioja
# Processing Record 25 of Set 11|truro
# Processing Record 26 of Set 11|pires do rio
# Processing Record 27 of Set 11|longido
# Processing Record 28 of Set 11|ntcheu
# Processing Record 29 of Set 11|asfi
# Processing Record 30 of Set 11|perrenjas
# City not found, skipping..
# Processing Record 31 of Set 11|xiamen
# Processing Record 32 of Set 11|miguel hidalgo
# Processing Record 33 of Set 11|bauta
# Processing Record 34 of Set 11|zhiryatino
# Processing Record 35 of Set 11|kikwit
# Processing Record 36 of Set 11|victor harbor
# Processing Record 37 of Set 11|gimli
# Processing Record 38 of Set 11|biu
# Processing Record 39 of Set 11|dalianwan
# Processing Record 40 of Set 11|tall kayf
# Processing Record 41 of Set 11|pagudpud
# Processing Record 42 of Set 11|matamoros
# Processing Record 43 of Set 11|baboua
# City not found, skipping..
# Processing Record 44 of Set 11|acarau
# Processing Record 45 of Set 11|hunza
# City not found, skipping..
# Processing Record 46 of Set 11|toliary
# City not found, skipping..
# Processing Record 47 of Set 11|seymchan
# Processing Record 48 of Set 11|shingu
# Processing Record 49 of Set 11|esmeraldas
# Processing Record 50 of Set 11|black river
# Processing Record 1 of Set 12|chagda
# City not found, skipping..
# Processing Record 2 of Set 12|passo fundo
# Processing Record 3 of Set 12|inderborskiy
# City not found, skipping..
# Processing Record 4 of Set 12|atar
# Processing Record 5 of Set 12|opuwo
# Processing Record 6 of Set 12|chino valley
# Processing Record 7 of Set 12|mulege
# Processing Record 8 of Set 12|chanasma
# Processing Record 9 of Set 12|colonial park
# Processing Record 10 of Set 12|mercedes
# Processing Record 11 of Set 12|yulara
# Processing Record 12 of Set 12|sentyabrskiy
# City not found, skipping..
# Processing Record 13 of Set 12|lang suan
# Processing Record 14 of Set 12|hengshan
# Processing Record 15 of Set 12|road town
# Processing Record 16 of Set 12|ponta delgada
# Processing Record 17 of Set 12|samba
# Processing Record 18 of Set 12|oistins
# Processing Record 19 of Set 12|russell
# Processing Record 20 of Set 12|merrill
# Processing Record 21 of Set 12|san jose
# Processing Record 22 of Set 12|palabuhanratu
# City not found, skipping..
# Processing Record 23 of Set 12|songea
# Processing Record 24 of Set 12|kitami
# Processing Record 25 of Set 12|half moon bay
# Processing Record 26 of Set 12|ellensburg
# Processing Record 27 of Set 12|ozernovskiy
# Processing Record 28 of Set 12|alta floresta
# Processing Record 29 of Set 12|tuatapere
# Processing Record 30 of Set 12|vangaindrano
# Processing Record 31 of Set 12|pueblo
# Processing Record 32 of Set 12|fairview
# Processing Record 33 of Set 12|madisonville
# Processing Record 34 of Set 12|sao gabriel da cachoeira
# Processing Record 35 of Set 12|chengde
# Processing Record 36 of Set 12|palauig
# Processing Record 37 of Set 12|dubti
# Processing Record 38 of Set 12|limbang
# Processing Record 39 of Set 12|baykit
# Processing Record 40 of Set 12|tessalit
# Processing Record 41 of Set 12|juba
# Processing Record 42 of Set 12|penzance
# Processing Record 43 of Set 12|yelizovo
# Processing Record 44 of Set 12|fenoarivo
# Processing Record 45 of Set 12|khorixas
# Processing Record 46 of Set 12|naze
# Processing Record 47 of Set 12|sondrio
# Processing Record 48 of Set 12|ponnani
# Processing Record 49 of Set 12|novouzensk
# Processing Record 50 of Set 12|bozoum
# Processing Record 1 of Set 13|hualmay
# Processing Record 2 of Set 13|tchaourou
# Processing Record 3 of Set 13|sept-iles
# Processing Record 4 of Set 13|da nang
# Processing Record 5 of Set 13|kavieng
# Processing Record 6 of Set 13|baghmara
# Processing Record 7 of Set 13|aurillac
# Processing Record 8 of Set 13|hope
# Processing Record 9 of Set 13|maralal
# Processing Record 10 of Set 13|terrace
# Processing Record 11 of Set 13|paris
# Processing Record 12 of Set 13|vestmannaeyjar
# Processing Record 13 of Set 13|okhotsk
# Processing Record 14 of Set 13|the valley
# Processing Record 15 of Set 13|rantepao
# Processing Record 16 of Set 13|seddon
# Processing Record 17 of Set 13|micheweni
# Processing Record 18 of Set 13|tafresh
# Processing Record 19 of Set 13|puerto escondido
# Processing Record 20 of Set 13|peruibe
# Processing Record 21 of Set 13|ust-maya
# Processing Record 22 of Set 13|presidente medici
# Processing Record 23 of Set 13|bosobolo
# Processing Record 24 of Set 13|rawannawi
# City not found, skipping..
# Processing Record 25 of Set 13|shihezi
# Processing Record 26 of Set 13|kawana waters
# City not found, skipping..
# Processing Record 27 of Set 13|sarangani
# Processing Record 28 of Set 13|myitkyina
# Processing Record 29 of Set 13|ixtapa
# Processing Record 30 of Set 13|krasnaya gora
# Processing Record 31 of Set 13|sobolevo
# Processing Record 32 of Set 13|bamako
# Processing Record 33 of Set 13|wad rawah
# Processing Record 34 of Set 13|pokhara
# Processing Record 35 of Set 13|sibolga
# Processing Record 36 of Set 13|biltine
# Processing Record 37 of Set 13|chulym
# Processing Record 38 of Set 13|berdigestyakh
# Processing Record 39 of Set 13|xining
# Processing Record 40 of Set 13|esfahan
# Processing Record 41 of Set 13|harper
# Processing Record 42 of Set 13|ngukurr
# City not found, skipping..
# Processing Record 43 of Set 13|assisi
# Processing Record 44 of Set 13|mwene-ditu
# Processing Record 45 of Set 13|hofn
# Processing Record 46 of Set 13|geresk
# City not found, skipping..
# Processing Record 47 of Set 13|lastoursville
# Processing Record 48 of Set 13|prince albert
# Processing Record 49 of Set 13|san martin
# Processing Record 50 of Set 13|amahai
# Processing Record 1 of Set 14|belmonte
# Processing Record 2 of Set 14|la union
# Processing Record 3 of Set 14|beringovskiy
# Processing Record 4 of Set 14|katherine
# Processing Record 5 of Set 14|altamont
# Processing Record 6 of Set 14|koumac
# Processing Record 7 of Set 14|dutse
# Processing Record 8 of Set 14|juye
# Processing Record 9 of Set 14|yaan
# Processing Record 10 of Set 14|san jeronimo
# Processing Record 11 of Set 14|hondo
# Processing Record 12 of Set 14|raduzhnyy
# Processing Record 13 of Set 14|dipkarpaz
# City not found, skipping..
# Processing Record 14 of Set 14|ijaki
# City not found, skipping..
# Processing Record 15 of Set 14|farmington
# Processing Record 16 of Set 14|nabire
# Processing Record 17 of Set 14|bairiki
# Processing Record 18 of Set 14|omsukchan
# Processing Record 19 of Set 14|mnogovershinnyy
# Processing Record 20 of Set 14|ojinaga
# Processing Record 21 of Set 14|waverly
# Processing Record 22 of Set 14|salinopolis
# Processing Record 23 of Set 14|springdale
# Processing Record 24 of Set 14|rockport
# Processing Record 25 of Set 14|camopi
# Processing Record 26 of Set 14|san pedro
# Processing Record 27 of Set 14|xai-xai
# Processing Record 28 of Set 14|oregon
# Processing Record 29 of Set 14|oussouye
# Processing Record 30 of Set 14|aykhal
# Processing Record 31 of Set 14|canon city
# Processing Record 32 of Set 14|husavik
# Processing Record 33 of Set 14|emerald
# Processing Record 34 of Set 14|tilichiki
# Processing Record 35 of Set 14|surt
# Processing Record 36 of Set 14|parkes
# Processing Record 37 of Set 14|mount gambier
# Processing Record 38 of Set 14|magdagachi
# Processing Record 39 of Set 14|pampa
# Processing Record 40 of Set 14|kiama
# Processing Record 41 of Set 14|aflu
# City not found, skipping..
# Processing Record 42 of Set 14|manzhouli
# Processing Record 43 of Set 14|pitimbu
# Processing Record 44 of Set 14|tautira
# Processing Record 45 of Set 14|gornoye loo
# Processing Record 46 of Set 14|naryan-mar
# Processing Record 47 of Set 14|kontagora
# Processing Record 48 of Set 14|tupik
# Processing Record 49 of Set 14|manama
# Processing Record 50 of Set 14|boatlaname
# City not found, skipping..
# Processing Record 1 of Set 15|antalaha
# Processing Record 2 of Set 15|malinyi
# Processing Record 3 of Set 15|kijang
# Processing Record 4 of Set 15|almaznyy
# Processing Record 5 of Set 15|tlapacoyan
# Processing Record 6 of Set 15|yar-sale
# Processing Record 7 of Set 15|zyukayka
# Processing Record 8 of Set 15|charlestown
# Processing Record 9 of Set 15|saint combs
# City not found, skipping..
# Processing Record 10 of Set 15|walvis bay
# Processing Record 11 of Set 15|pimentel
# Processing Record 12 of Set 15|lubao
# Processing Record 13 of Set 15|buala
# Processing Record 14 of Set 15|flin flon
# Processing Record 15 of Set 15|kuhestan
# City not found, skipping..
# Processing Record 16 of Set 15|bakchar
# Processing Record 17 of Set 15|sinfra
# Processing Record 18 of Set 15|mecca
# Processing Record 19 of Set 15|san nicolas
# Processing Record 20 of Set 15|lukovetskiy
# Processing Record 21 of Set 15|vaitape
# Processing Record 22 of Set 15|chimore
# Processing Record 23 of Set 15|bereznehuvate
# Processing Record 24 of Set 15|berlevag
# Processing Record 25 of Set 15|yaqui
# Processing Record 26 of Set 15|carutapera
# Processing Record 27 of Set 15|yashkul
# Processing Record 28 of Set 15|amapa
# Processing Record 29 of Set 15|khonsar
# City not found, skipping..
# Processing Record 30 of Set 15|madikeri
# Processing Record 31 of Set 15|alamos
# Processing Record 32 of Set 15|leova
# Processing Record 33 of Set 15|vanimo
# Processing Record 34 of Set 15|mehran
# Processing Record 35 of Set 15|samarai
# Processing Record 36 of Set 15|roma
# Processing Record 37 of Set 15|jijiga
# Processing Record 38 of Set 15|brae
# Processing Record 39 of Set 15|haibowan
# City not found, skipping..
# Processing Record 40 of Set 15|shenxian
# Processing Record 41 of Set 15|kamaishi
# Processing Record 42 of Set 15|olinda
# Processing Record 43 of Set 15|gelemso
# Processing Record 44 of Set 15|evensk
# Processing Record 45 of Set 15|neiafu
# Processing Record 46 of Set 15|grand forks
# Processing Record 47 of Set 15|ramganj
# Processing Record 48 of Set 15|adre
# Processing Record 49 of Set 15|libreville
# ------------------
# Data Retrieval Complete
# ------------------

# %%
len(city_data)
# Out:
# 684

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Jerez      GT  14.1000  -89.7500     81.05        47           0
# 1      Saldanha      ZA -33.0117   17.9442     59.05        80          19
# 2  Norman Wells      CA  65.2820 -126.8329    -34.56        67          40
# 3    Butaritari      KI   3.0707  172.7902     81.97        78          62
# 4    Den Helder      NL  52.9599    4.7593     51.78        95          90
# 5      Thompson      CA  55.7435  -97.8558     14.16        85          90
# 6   Fort Morgan      US  40.2503 -103.8000     53.82        27           1
# 7       Ushuaia      AR -54.8000  -68.3000     51.46        58          40
# 8       Madison      US  34.7334  -86.5667     60.15        62           1
# 9      Boralday      KZ  43.3578   76.8594     30.06        93          90
#
#    Wind Speed Current Description
# 0        3.44           clear sky
# 1       13.33          few clouds
# 2        2.30    scattered clouds
# 3        9.57          light rain
# 4       15.01     overcast clouds
# 5        6.91          light snow
# 6        4.61                haze
# 7       26.46    scattered clouds
# 8        3.00           clear sky
# 9        4.47                mist
